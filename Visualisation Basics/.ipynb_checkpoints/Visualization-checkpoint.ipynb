# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %% [markdown]
# # Matplotlib

# %%
x = [0,1,2]
y = [100,200,300]

# %%
plt.plot(x,y)
plt.show()

# %%
housing = pd.DataFrame({'rooms':[1,1,1,1,1,2,2,2,2,3],'price':[100,100,100,100,100,200,230,240,250,290]})

# %%
housing
# Out:
#    rooms  price
# 0      1    100
# 1      1    100
# 2      1    100
# 3      1    100
# 4      1    100
# 5      2    200
# 6      2    230
# 7      2    240
# 8      2    250
# 9      3    290

# %%
plt.scatter(housing['rooms'],housing['price'])

# %%
plt.plot(x,y,color='red',marker='o',markersize=15,linestyle='--')

plt.xlim(0,2)
plt.ylim(0,300)

plt.title('Tile')
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# # Seaborn

# %%
df1 = pd.read_csv('../References/DATA/heart.csv')

# %%
df1
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.displot(df1['age'],color='red')

# %%
df1.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
sns.countplot(x='cp',data=df1)
# Out:
# <AxesSubplot:xlabel='cp', ylabel='count'>

# %%
sns.countplot(x='cp',hue='sex',data=df1)
# Out:
# <AxesSubplot:xlabel='cp', ylabel='count'>

# %% [markdown]
# ## Box Plot

# %%
sns.boxplot(x='target',y='age',data=df1,hue='sex')
# Out:
# <AxesSubplot:xlabel='target', ylabel='age'>

# %%
df1.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.scatterplot(x='chol',y='trestbps',data=df1,hue='sex',size='age',palette='Dark2')
# Out:
# <AxesSubplot:xlabel='chol', ylabel='trestbps'>

# %%
iris = pd.read_csv('../References/DATA/iris.csv')

# %%
sns.pairplot(iris,hue='species')
